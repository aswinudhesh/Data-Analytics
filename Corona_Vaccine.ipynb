# %% [markdown]
# <a href="https://colab.research.google.com/github/aswinudhesh/Data-Analytics/blob/main/Corona_Vaccine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from tabulate import tabulate
import traceback
import numpy as np
import matplotlib.pyplot as plt
from requests import get
import requests
import os

# %%
import pandas as pd
df1 = pd.read_csv('/content/us-counties.csv')
df2 = pd.read_csv('/content/us-counties-recent.csv')
#merge dataframe of two csv files
df= pd.merge(df1,df2, on = 'county')
df.head()
# Out:
#        date_x   county  state_x  fips_x  cases_x  deaths_x  confirmed_cases  \
# 0  2022-01-10  Autauga  Alabama  1001.0    12029     162.0           9755.0
# 1  2022-01-10  Autauga  Alabama  1001.0    12029     162.0           9755.0
# 2  2022-01-10  Autauga  Alabama  1001.0    12029     162.0           9755.0
# 3  2022-01-10  Autauga  Alabama  1001.0    12029     162.0           9755.0
# 4  2022-01-10  Autauga  Alabama  1001.0    12029     162.0           9755.0
#
#    confirmed_deaths  probable_cases  probable_deaths      date_y  state_y  \
# 0             144.0          2274.0             18.0  2021-12-11  Alabama
# 1             144.0          2274.0             18.0  2021-12-12  Alabama
# 2             144.0          2274.0             18.0  2021-12-13  Alabama
# 3             144.0          2274.0             18.0  2021-12-14  Alabama
# 4             144.0          2274.0             18.0  2021-12-15  Alabama
#
#    fips_y  cases_y  deaths_y
# 0  1001.0    10596     158.0
# 1  1001.0    10599     158.0
# 2  1001.0    10605     158.0
# 3  1001.0    10637     158.0
# 4  1001.0    10641     158.0

# %%
list(df.head())
# Out:
# ['date_x',
#  'county',
#  'state_x',
#  'fips_x',
#  'cases_x',
#  'deaths_x',
#  'confirmed_cases',
#  'confirmed_deaths',
#  'probable_cases',
#  'probable_deaths',
#  'date_y',
#  'state_y',
#  'fips_y',
#  'cases_y',
#  'deaths_y']

# %%
df.tail(10)
# Out:
#             date_x  county  state_x   fips_x  cases_x  deaths_x  \
# 478520  2022-01-10  Weston  Wyoming  56045.0     1268      16.0
# 478521  2022-01-10  Weston  Wyoming  56045.0     1268      16.0
# 478522  2022-01-10  Weston  Wyoming  56045.0     1268      16.0
# 478523  2022-01-10  Weston  Wyoming  56045.0     1268      16.0
# 478524  2022-01-10  Weston  Wyoming  56045.0     1268      16.0
# 478525  2022-01-10  Weston  Wyoming  56045.0     1268      16.0
# 478526  2022-01-10  Weston  Wyoming  56045.0     1268      16.0
# 478527  2022-01-10  Weston  Wyoming  56045.0     1268      16.0
# 478528  2022-01-10  Weston  Wyoming  56045.0     1268      16.0
# 478529  2022-01-10  Weston  Wyoming  56045.0     1268      16.0
#
#         confirmed_cases  confirmed_deaths  probable_cases  probable_deaths  \
# 478520            961.0               NaN           307.0              NaN
# 478521            961.0               NaN           307.0              NaN
# 478522            961.0               NaN           307.0              NaN
# 478523            961.0               NaN           307.0              NaN
# 478524            961.0               NaN           307.0              NaN
# 478525            961.0               NaN           307.0              NaN
# 478526            961.0               NaN           307.0              NaN
# 478527            961.0               NaN           307.0              NaN
# 478528            961.0               NaN           307.0              NaN
# 478529            961.0               NaN           307.0              NaN
#
#             date_y  state_y   fips_y  cases_y  deaths_y
# 478520  2021-12-31  Wyoming  56045.0     1254      14.0
# 478521  2022-01-01  Wyoming  56045.0     1254      14.0
# 478522  2022-01-02  Wyoming  56045.0     1254      14.0
# 478523  2022-01-03  Wyoming  56045.0     1257      14.0
# 478524  2022-01-04  Wyoming  56045.0     1257      16.0
# 478525  2022-01-05  Wyoming  56045.0     1260      16.0
# 478526  2022-01-06  Wyoming  56045.0     1261      16.0
# 478527  2022-01-07  Wyoming  56045.0     1263      16.0
# 478528  2022-01-08  Wyoming  56045.0     1263      16.0
# 478529  2022-01-09  Wyoming  56045.0     1263      16.0
