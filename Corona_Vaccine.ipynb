# %% [markdown]
# <a href="https://colab.research.google.com/github/aswinudhesh/Data-Analytics/blob/main/Corona_Vaccine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import re
import random
import traceback
from tabulate import tabulate
import pandas as pd
import numpy as np
from datetime import datetime
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df1 = pd.read_csv('/content/drive/MyDrive/dataset/dataset_csv/dataset-covid-2/us-counties-recent.csv')
df2 = pd.read_csv('/content/drive/MyDrive/dataset/dataset_csv/dataset-covid-2/us-counties.csv')
df1.head(5)
df2.head()
# Out:
#          date   county    state    fips  cases  deaths
# 0  2021-12-11  Autauga  Alabama  1001.0  10596   158.0
# 1  2021-12-11  Baldwin  Alabama  1003.0  38307   591.0
# 2  2021-12-11  Barbour  Alabama  1005.0   3716    81.0
# 3  2021-12-11     Bibb  Alabama  1007.0   4379    95.0
# 4  2021-12-11   Blount  Alabama  1009.0  10857   193.0
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1     0.0
# 1  2020-01-22  Snohomish  Washington  53061.0      1     0.0
# 2  2020-01-23  Snohomish  Washington  53061.0      1     0.0
# 3  2020-01-24       Cook    Illinois  17031.0      1     0.0
# 4  2020-01-24  Snohomish  Washington  53061.0      1     0.0

# %%
df_new = pd.merge(df1, df2, how='outer')
df_new.head(5)
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1     0.0
# 1  2020-01-22  Snohomish  Washington  53061.0      1     0.0
# 2  2020-01-23  Snohomish  Washington  53061.0      1     0.0
# 3  2020-01-24       Cook    Illinois  17031.0      1     0.0
# 4  2020-01-24  Snohomish  Washington  53061.0      1     0.0

# %% [markdown]
# # 1) Top 10 states having highest total death in year 2020

# %%
def getyear(row):
  return datetime.datetime.strptime(row["date"], "%Y-%m-%d").year # Call strptime from the datetime class

df_new["year"] = df_new.apply(getyear, axis=1)
df_in2020 = df_new.where(df_new["year"] == 2020)
df_top10 = df_in2020.groupby(["state"])["deaths"].sum().to_frame("count").reset_index()
df_top10_2020 = df_top10.sort_values(by="count", ascending=False)
df_top10_2020.head(10)
# Out:
#             state      count
# 33       New York  8320598.0
# 31     New Jersey  3817150.0
# 4      California  3065113.0
# 46          Texas  2927740.0
# 9         Florida  2632238.0
# 22  Massachusetts  2222455.0
# 14       Illinois  2211390.0
# 40   Pennsylvania  2002629.0
# 23       Michigan  1837617.0
# 10        Georgia  1363977.0

# %% [markdown]
# # 2) Top 10 states having highest total death in the year 2021

# %%
def getyear(row):
  return datetime.datetime.strptime(row["date"], "%Y-%m-%d").year # Call strptime from the datetime class

df_new["year"] = df_new.apply(getyear, axis=1)
df_in2021 = df_new.where(df_new["year"] == 2021)
df_top10 = df_in2021.groupby(["state"])["deaths"].sum().to_frame("count").reset_index()
df_top10_2021 = df_top10.sort_values(by="count", ascending=False)
df_top10_2021.head(10)
# Out:
#            state       count
# 5     California  22532428.0
# 47         Texas  20088968.0
# 34      New York  18918470.0
# 10       Florida  15333245.0
# 41  Pennsylvania  10025434.0
# 32    New Jersey   9406432.0
# 15      Illinois   9306526.0
# 11       Georgia   7791745.0
# 24      Michigan   7460163.0
# 38          Ohio   7327426.0

# %% [markdown]
# # 3) Top 10 states having highest average death in the year 2020

# %%
def getyear(row):
  return datetime.datetime.strptime(row["date"], "%Y-%m-%d").year # Call strptime from the datetime class

df_new["year"] = df_new.apply(getyear, axis=1)
df_in2020 = df_new.where(df_new["year"] == 2020)
df_top10 = df_in2020.groupby(["state"])["deaths"].mean().to_frame("count").reset_index()
df_top10_2020 = df_top10.sort_values(by="count", ascending=False)
df_top10_2020.head(10)
# Out:
#                    state       count
# 31            New Jersey  590.798638
# 22         Massachusetts  500.102385
# 33              New York  495.037958
# 8   District of Columbia  487.983333
# 41           Puerto Rico  457.537415
# 6            Connecticut  429.230740
# 2                Arizona  238.422596
# 4             California  182.436343
# 42          Rhode Island  152.694639
# 9                Florida  135.000410

# %% [markdown]
# # 4) Top 10 states having highest average death in the year 2021

# %%
def getyear(row):
  return datetime.datetime.strptime(row["date"], "%Y-%m-%d").year # Call strptime from the datetime class

df_new["year"] = df_new.apply(getyear, axis=1)
df_in2021 = df_new.where(df_new["year"] == 2021)
df_top10 = df_in2021.groupby(["state"])["deaths"].mean().to_frame("count").reset_index()
df_top10_2021 = df_top10.sort_values(by="count", ascending=False)
df_top10_2021.head(10)
# Out:
#                    state        count
# 42           Puerto Rico  2574.764384
# 3                Arizona  1196.586783
# 23         Massachusetts  1174.260274
# 32            New Jersey  1171.411208
# 9   District of Columbia  1105.120548
# 5             California  1064.004722
# 7            Connecticut   906.108676
# 34              New York   893.645253
# 10               Florida   617.777800
# 43          Rhode Island   444.803653

# %% [markdown]
# # 5) Top 10 county having highest total death in 2020 and 2021 year together

# %%
df_new["year"] = df_new.apply(getyear, axis=1)
dfboth2021_21 = df_new.where(df_new["year"] == 2020 & 2021)
df_top10 = dfboth2021_21.groupby(["state"])["deaths"].sum().to_frame("count").reset_index()
df_top10_2021_21 = df_top10.sort_values(by="count", ascending=False)
df_top10_2021.head(10)
# Out:
#                    state        count
# 42           Puerto Rico  2574.764384
# 3                Arizona  1196.586783
# 23         Massachusetts  1174.260274
# 32            New Jersey  1171.411208
# 9   District of Columbia  1105.120548
# 5             California  1064.004722
# 7            Connecticut   906.108676
# 34              New York   893.645253
# 10               Florida   617.777800
# 43          Rhode Island   444.803653

# %% [markdown]
# # 6) Find/print all pair of counties that have the same name but belong to two different states

# %%
dict_countystates = dict(zip(df_new.state, df_new.county))
print(dict_countystates)
arr_county_state = list(dict_countystates.items())
df_county_states = pd.DataFrame(arr_county_state, columns=['county','state'])
df_top10_2020_21 = df_new.groupby(["county"]).size().to_frame('count').reset_index()
df_top10_2020_21 = df_top10_2020_21.where(df_top10_2020_21['count'] >= 2)
# Out:
# {'Washington': 'Yakima', 'Illinois': 'Woodford', 'California': 'Yuba', 'Arizona': 'Yuma', 'Massachusetts': 'Worcester', 'Wisconsin': 'Wood', 'Texas': 'Zavala', 'Nebraska': 'York', 'Utah': 'Weber', 'Oregon': 'Yamhill', 'Florida': 'Washington', 'New York': 'Yates', 'Rhode Island': 'Washington', 'Georgia': 'Worth', 'New Hampshire': 'Unknown', 'North Carolina': 'Yancey', 'New Jersey': 'Warren', 'Nevada': 'White Pine', 'Colorado': 'Yuma', 'Maryland': 'Worcester', 'Tennessee': 'Wilson', 'South Carolina': 'York', 'Pennsylvania': 'York', 'Kentucky': 'Woodford', 'Hawaii': 'Unknown', 'Indiana': 'Whitley', 'Minnesota': 'Yellow Medicine', 'Oklahoma': 'Woodward', 'Vermont': 'Windsor', 'District of Columbia': 'District of Columbia', 'Virginia': 'York', 'Kansas': 'Wyandotte', 'Missouri': 'Wright', 'Connecticut': 'Windham', 'Iowa': 'Wright', 'Ohio': 'Wyandot', 'Louisiana': 'Winn', 'South Dakota': 'Ziebach', 'Michigan': 'Wexford', 'New Mexico': 'Valencia', 'Mississippi': 'Yazoo', 'Arkansas': 'Yell', 
# ...

# %%
 df1 = pd.read_csv("/content/drive/MyDrive/dataset/dataset_csv/dataset-covid-2/us-counties-recent.csv")
df2 = pd.read_csv("/content/drive/MyDrive/dataset/dataset_csv/dataset-covid-2/us-counties.csv")
df3 = pd.read_csv("/content/drive/MyDrive/dataset/dataset_csv/dataset-covid-2/us-states.csv")
df4 = pd.read_csv("/content/drive/MyDrive/dataset/dataset_csv/dataset-covid-2/us.csv")

# %%
df1.head(5)
df2.head(5)
# Out:
#          date   county    state    fips  cases  deaths
# 0  2021-12-11  Autauga  Alabama  1001.0  10596   158.0
# 1  2021-12-11  Baldwin  Alabama  1003.0  38307   591.0
# 2  2021-12-11  Barbour  Alabama  1005.0   3716    81.0
# 3  2021-12-11     Bibb  Alabama  1007.0   4379    95.0
# 4  2021-12-11   Blount  Alabama  1009.0  10857   193.0
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1     0.0
# 1  2020-01-22  Snohomish  Washington  53061.0      1     0.0
# 2  2020-01-23  Snohomish  Washington  53061.0      1     0.0
# 3  2020-01-24       Cook    Illinois  17031.0      1     0.0
# 4  2020-01-24  Snohomish  Washington  53061.0      1     0.0

# %%
df_new = pd.merge(df1, df2, how='outer')
df_new.head(10)
# Out:
#          date       county       state     fips  cases  deaths
# 0  2020-01-21    Snohomish  Washington  53061.0      1     0.0
# 1  2020-01-22    Snohomish  Washington  53061.0      1     0.0
# 2  2020-01-23    Snohomish  Washington  53061.0      1     0.0
# 3  2020-01-24         Cook    Illinois  17031.0      1     0.0
# 4  2020-01-24    Snohomish  Washington  53061.0      1     0.0
# 5  2020-01-25         Cook    Illinois  17031.0      1     0.0
# 6  2020-01-25       Orange  California   6059.0      1     0.0
# 7  2020-01-25    Snohomish  Washington  53061.0      1     0.0
# 8  2020-01-26         Cook    Illinois  17031.0      1     0.0
# 9  2020-01-26  Los Angeles  California   6037.0      1     0.0

# %% [markdown]
# # 7 a) Top 10 least death states in 2020

# %%
def get_year(row):
    return datetime.strptime(row['date'], '%Y-%m-%d').year

df_new['year'] = df_new.apply(get_year, axis=1)
#filtering the data on 2020
df_2020 = df_new.where(df_new['year'] == 2020)
df_top10_2020 = df_2020.groupby(['state'])['deaths'].sum().to_frame('count').reset_index()
df_top10_2020 = df_top10_2020.sort_values(by=['count'], ascending=True)

def rank(row):
    return int( 56 - row['rank1'])

df_top10_2020['rank1'] = df_top10_2020['count'].rank(ascending = False )
df_top10_2020['rank'] = df_top10_2020.apply(rank, axis=1)
df_top10_2020_sel = df_top10_2020[['state', 'count', 'rank']]
df_top10_2020_sel.head(10)
# Out:
#                        state    count  rank
# 36  Northern Mariana Islands    544.0     1
# 49            Virgin Islands   3503.0     2
# 11                      Guam  10424.0     3
# 1                     Alaska  13147.0     4
# 48                   Vermont  16434.0     5
# 54                   Wyoming  20734.0     6
# 12                    Hawaii  27227.0     7
# 20                     Maine  35654.0     8
# 27                   Montana  58866.0     9
# 52             West Virginia  84127.0    10

# %% [markdown]
# # b) Top 10 least death states in 2021

# %%
def get_year(row):
    return datetime.strptime(row['date'], '%Y-%m-%d').year

df_new['year'] = df_new.apply(get_year, axis=1)
#filtering the data on 2021
df_2021 = df_new.where(df_new['year'] == 2021)
df_top10_2021 = df_2021.groupby(['state'])['deaths'].sum().to_frame('count').reset_index()
df_top10_2021 = df_top10_2021.sort_values(by=['count'], ascending=True)

def rank(row):
    return int( 56 - row['rank1'])

df_top10_2021['rank1'] = df_top10_2021['count'].rank(ascending = False )
df_top10_2021['rank'] = df_top10_2021.apply(rank, axis=1)
df_top10_2021_sel = df_top10_2021[['state', 'count', 'rank']]
df_top10_2021_sel.head(10)
# Out:
#                        state     count  rank
# 2             American Samoa       0.0     0
# 37  Northern Mariana Islands     926.0     1
# 50            Virgin Islands   16615.0     2
# 12                      Guam   61389.0     3
# 49                   Vermont  100847.0     4
# 1                     Alaska  163285.0     5
# 13                    Hawaii  222578.0     6
# 55                   Wyoming  316182.0     7
# 21                     Maine  328660.0     8
# 9       District of Columbia  403369.0     9

# %% [markdown]
# # 8 a)Top 10 least death states in last three months of the year 2021

# %%
df_new['date'] = pd.to_datetime(df_new['date']) # Convert 'date' column to datetime objects
# Filter data for the last three months of 2021
df_last_3_months_2021 = df_new[(df_new['date'] >= '2021-10-01') & (df_new['date'] <= '2021-12-31')]
# Group by state and sum deaths for the last three months of 2021
df_top10_last_3_months_2021 = df_last_3_months_2021.groupby(['state'])['deaths'].sum().to_frame('count').reset_index()
# Sort by the total deaths in ascending order
df_top10_last_3_months_2021 = df_top10_last_3_months_2021.sort_values(by=['count'], ascending=True)
df_top10_last_3_months_2021['rank1'] = df_top10_last_3_months_2021['count'].rank(ascending=False) # Assign ranks

def rank(row):
    return int(56 - row['rank1'])

df_top10_last_3_months_2021['rank'] = df_top10_last_3_months_2021.apply(rank, axis=1)
# Select relevant columns
df_top10_last_3_months_2021_sel = df_top10_last_3_months_2021[['state', 'count', 'rank']]
# Display the top 10 states with the least deaths in the last three months of 2021
df_top10_last_3_months_2021_sel.head(10)
# Out:
#                        state     count  rank
# 2             American Samoa       0.0     0
# 37  Northern Mariana Islands     380.0     1
# 50            Virgin Islands    7588.0     2
# 12                      Guam   22934.0     3
# 49                   Vermont   36152.0     4
# 1                     Alaska   71389.0     5
# 13                    Hawaii   88570.0     6
# 9       District of Columbia  109817.0     7
# 21                     Maine  115144.0     8
# 55                   Wyoming  119311.0     9

# %% [markdown]
# # b) Top 10 most death states in last three months of the year 2021

# %%
df_new['date'] = pd.to_datetime(df_new['date']) # Convert 'date' column to datetime objects
# Filter data for the last three months of 2021
df_last_3_months_2021 = df_new[(df_new['date'] >= '2021-10-01') & (df_new['date'] <= '2021-12-31')]
# Group by state and sum deaths for the last three months of 2021
df_top10_last_3_months_2021 = df_last_3_months_2021.groupby(['state'])['deaths'].sum().to_frame('count').reset_index()
# Sort by the total deaths in descending order
df_top10_last_3_months_2021 = df_top10_last_3_months_2021.sort_values(by=['count'], ascending=False)
# Assign ranks
df_top10_last_3_months_2021['rank1'] = df_top10_last_3_months_2021['count'].rank(ascending=False)

def rank(row):
    return int(row['rank1'])

df_top10_last_3_months_2021['rank'] = df_top10_last_3_months_2021.apply(rank, axis=1)
# Select relevant columns
df_top10_last_3_months_2021_sel = df_top10_last_3_months_2021[['state', 'count', 'rank']]
# Display the top 10 states with the most deaths in the last three months of 2021
df_top10_last_3_months_2021_sel.head(10)
# Out:
#            state      count  rank
# 5     California  6747934.0     1
# 47         Texas  6662147.0     2
# 10       Florida  5532804.0     3
# 34      New York  5212313.0     4
# 41  Pennsylvania  3005360.0     5
# 15      Illinois  2679721.0     6
# 11       Georgia  2620343.0     7
# 32    New Jersey  2593734.0     8
# 38          Ohio  2354719.0     9
# 24      Michigan  2297090.0    10
