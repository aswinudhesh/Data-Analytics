# %% [markdown]
# <a href="https://colab.research.google.com/github/aswinudhesh/pythontutorial/blob/main/Mini_Project_Powerlifiting_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from tabulate import tabulate

# %%
import pandas as pd
df = pd.read_csv("/openpowerlifting-2021-12-10-b420db66.csv")
df
# Out:
# <ipython-input-5-3ed620caec70>:2: DtypeWarning: Columns (33,35,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/openpowerlifting-2021-12-10-b420db66.csv")
#                          Name Sex Event   Equipment   Age AgeClass  \
# 0                 Alona Vladi   F   SBD         Raw  33.0    24-34
# 1          Galina Solovyanova   F   SBD         Raw  43.0    40-44
# 2              Daniil Voronin   M   SBD         Raw  15.5    16-17
# 3              Aleksey Krasov   M   SBD         Raw  35.0    35-39
# 4      Margarita Pleschenkova   M   SBD         Raw  26.5    24-34
# ...                       ...  ..   ...         ...   ...      ...
# 84002        Barry O'Sullivan   M     S  Single-ply  33.0    24-34
# 84003        Joel Evangelista   M     S  Single-ply  23.0    20-23
# 84004        Joel Evangelista   M     S  Single-ply  23.0    20-23
# 84005          Frances Arthur   F     B         Raw  40.0    40-44
# 84006           Shauna Madden   F     B          Ra   NaN      NaN
#
#       BirthYearClass Division  BodyweightKg WeightClassKg  ...  Tested  \
# 0              24-39        O         58.30            60  ...     Yes
# 1              40-49       M1         73.10            75  ...     Yes
# 2              14-18        T         67.40            75  ...     Yes
# 3              24-39        O         66.65            75  ...     Yes
# 4              24-39        O         72.45            75  ...     Yes
# ...              ...      ...           ...           ...  ...     ...
# 84002          24-39      M-O        109.30           110  ...     Yes
# 84003            NaN      M-O        127.00           145  ...     Yes
# 84004            NaN     M-JR        127.00           145  ...     Yes
# 84005          40-49      F-O         49.10          50.5  ...     Yes
# 84006            NaN      NaN           NaN           NaN  ...     NaN
#
#        Country  State  Federation  ParentFederation        Date  MeetCountry  \
# 0       Russia    NaN         GFP               NaN  2019-05-11       Russia
# 1       Russia    NaN         GFP               NaN  2019-05-11       Russia
# 2       Russia    NaN         GFP               NaN  2019-05-11       Russia
# 3       Russia    NaN         GFP               NaN  2019-05-11       Russia
# 4       Russia    NaN         GFP               NaN  2019-05-11       Russia
# ...        ...    ...         ...               ...         ...          ...
# 84002      NaN    NaN       IDFPF             WDFPF  2017-02-18      Ireland
# 84003  Ireland    NaN       IDFPF             WDFPF  2017-02-18      Ireland
# 84004  Ireland    NaN       IDFPF             WDFPF  2017-02-18      Ireland
# 84005  Ireland    NaN       IDFPF             WDFPF  2017-02-18      Ireland
# 84006      NaN    NaN         NaN               NaN         NaN          NaN
#
#        MeetState       MeetTown               MeetName
# 0            NaN        Bryansk        Open Tournament
# 1            NaN        Bryansk        Open Tournament
# 2            NaN        Bryansk        Open Tournament
# 3            NaN        Bryansk        Open Tournament
# 4            NaN        Bryansk        Open Tournament
# ...          ...            ...                    ...
# 84002        NaN  Castleblayney  National Single Lifts
# 84003        NaN  Castleblayney  National Single Lifts
# 84004        NaN  Castleblayney  National Single Lifts
# 84005        NaN  Castleblayney  National Single Lifts
# 84006        NaN            NaN                    NaN
#
# [84007 rows x 41 columns]

# %%
list(df.columns)
# Out:
# ['Name',
#  'Sex',
#  'Event',
#  'Equipment',
#  'Age',
#  'AgeClass',
#  'BirthYearClass',
#  'Division',
#  'BodyweightKg',
#  'WeightClassKg',
#  'Squat1Kg',
#  'Squat2Kg',
#  'Squat3Kg',
#  'Squat4Kg',
#  'Best3SquatKg',
#  'Bench1Kg',
#  'Bench2Kg',
#  'Bench3Kg',
#  'Bench4Kg',
#  'Best3BenchKg',
#  'Deadlift1Kg',
#  'Deadlift2Kg',
#  'Deadlift3Kg',
#  'Deadlift4Kg',
#  'Best3DeadliftKg',
#  'TotalKg',
#  'Place',
#  'Dots',
#  'Wilks',
#  'Glossbrenner',
#  'Goodlift',
#  'Tested',
#  'Country',
#  'State',
#  'Federation',
#  'ParentFederation',
#  'Date',
#  'MeetCountry',
#  'MeetState',
#  'MeetTown',
#  'MeetName']

# %%
df.tail(10)
# Out:
#                    Name Sex Event Equipment   Age AgeClass BirthYearClass  \
# 375172     Jessica Raze   F   SBD       Raw  27.5    24-34          24-39
# 375173     Rachel Leach   F   SBD       Raw  23.5    24-34          24-39
# 375174      Leah Austin   F   SBD       Raw  51.5    50-54          50-59
# 375175   Jeanne Murdock   F   SBD       Raw  65.0    65-69          60-69
# 375176     Esther Scott   F   SBD       Raw  33.5    24-34          24-39
# 375177  Nicci Pritchett   F   SBD       Raw  29.5    24-34          24-39
# 375178       Nora Sanzo   F   SBD       Raw  23.5    24-34          24-39
# 375179     Keanne Henry   F   SBD       Raw  40.5    40-44          40-49
# 375180     Tara Torlone   F   SBD       Raw  35.5    35-39          24-39
# 375181    Lyndsey Smith   F   SBD       Raw  28.5    24-34             24
#
#        Division  BodyweightKg WeightClassKg  ...  Tested  Country  State  \
# 375172     FR-O          61.9            63  ...     Yes      USA     VA
# 375173     FR-O          57.4            63  ...     Yes      USA     VA
# 375174     FR-O          62.2            63  ...     Yes      USA     VA
# 375175     FR-O          62.7            63  ...     Yes      USA     VA
# 375176     FR-O          71.7            72  ...     Yes      USA     VA
# 375177     FR-O          67.4            72  ...     Yes      USA     VA
# 375178     FR-O          70.9            72  ...     Yes      USA     VA
# 375179     FR-O          69.1            72  ...     Yes      USA     MD
# 375180     FR-O          66.6            72  ...     Yes      USA     VA
# 375181      NaN           NaN           NaN  ...     NaN      NaN    NaN
#
#         Federation  ParentFederation        Date  MeetCountry  MeetState  \
# 375172       USAPL               IPF  2018-06-09          USA         VA
# 375173       USAPL               IPF  2018-06-09          USA         VA
# 375174       USAPL               IPF  2018-06-09          USA         VA
# 375175       USAPL               IPF  2018-06-09          USA         VA
# 375176       USAPL               IPF  2018-06-09          USA         VA
# 375177       USAPL               IPF  2018-06-09          USA         VA
# 375178       USAPL               IPF  2018-06-09          USA         VA
# 375179       USAPL               IPF  2018-06-09          USA         VA
# 375180       USAPL               IPF  2018-06-09          USA         VA
# 375181         NaN               NaN         NaN          NaN        NaN
#
#         MeetTown             MeetName
# 375172       NaN  Battle at the Beach
# 375173       NaN  Battle at the Beach
# 375174       NaN  Battle at the Beach
# 375175       NaN  Battle at the Beach
# 375176       NaN  Battle at the Beach
# 375177       NaN  Battle at the Beach
# 375178       NaN  Battle at the Beach
# 375179       NaN  Battle at the Beach
# 375180       NaN  Battle at the Beach
# 375181       NaN                  NaN
#
# [10 rows x 41 columns]

# %% [markdown]
# # 1. Top 10 states for Men.

# %%
import pandas as pd
from tabulate import tabulate
df_state_men = df.loc[df["Sex"]=="M"].groupby(["State"]).size().to_frame("count").reset_index()
df1 = df_state_men.sort_values(by="count",ascending=False)
print("Top 10 states for Men")
print(tabulate(df1.head(10), headers='keys', tablefmt='psql'))
# Out:
# Top 10 states for Men
# +----+---------+---------+
# |    | State   |   count |
# |----+---------+---------|
# | 52 | VA      |    1621 |
# | 29 | NC      |    1559 |
# | 42 | PA      |    1276 |
# | 21 | MD      |     585 |
# | 37 | NY      |     470 |
# |  3 | AZ      |     436 |
# | 38 | OH      |     246 |
# | 10 | FL      |     194 |
# | 31 | NE      |     179 |
# |  7 | CT      |     161 |
# +----+---------+---------+

# %% [markdown]
# # 2. Top 10 states for Women.

# %%
import pandas as pd
from tabulate import tabulate
df_state_women = df.loc[df["Sex"]=="F"].groupby(["State"]).size().to_frame("count").reset_index()
df1 = df_state_women.sort_values(by="count",ascending=False)
print("Top 10 states for Women")
print(tabulate(df1.head(10), headers='keys', tablefmt='psql'))
# Out:
# Top 10 states for Women
# +----+---------+---------+
# |    | State   |   count |
# |----+---------+---------|
# | 40 | VA      |     717 |
# | 22 | NC      |     611 |
# | 33 | PA      |     397 |
# |  3 | AZ      |     180 |
# | 29 | NY      |     169 |
# | 16 | MD      |     165 |
# | 14 | KY      |      90 |
# |  8 | DC      |      88 |
# | 15 | MA      |      76 |
# |  7 | CT      |      74 |
# +----+---------+---------+

# %% [markdown]
# #3. Plot pie chart and bar chart for Men Top 21-30 states (inclusive).

# %%
import matplotlib.pyplot as plt

data = {"OK": 5075, "BC": 4823, "TN": 4680, "OR": 4632, "NM": 4364,
        "MI": 4330, "AB": 4184, "AL": 4184, "IN": 4036, "NV": 3746}

colors = ["blue", "orange", "green", "red", "violet",
          "brown", "pink", "grey", "yellow", "maroon"]

plt.pie(list(data.values()), labels=data.keys(), colors=colors,
        autopct='%2.1f%%', shadow=True, startangle=0)

plt.axis("equal")
plt.show()

# %%
plt.bar(data.keys(), data.values(), color="blue")
plt.xlabel("States")
plt.ylabel("Number of Male Powerlifters")
plt.title("Bar Chart For Top 21 to 30 States for Men")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #4. Plot pie chart and bar chart for Women Top 21-30 states (inclusive).

# %%
import matplotlib.pyplot as plt

data = {"IL": 2184, "MA": 2174, "NJ": 2169, "MI": 2115, "AB": 1870,
        "BC": 1744, "IN": 1733, "HI": 1717, "AL": 1343, "OK": 1337}

colors = ["blue", "orange", "green", "red", "violet",
          "brown", "pink", "grey", "yellow", "maroon"]

plt.pie(list(data.values()), labels=data.keys(), colors=colors,
        autopct='%2.1f%%', shadow=True, startangle=0) #here the starting angle is the origin "0"

plt.axis("equal")
plt.show()

# %%
plt.bar(data.keys(), data.values(), color="blue")
plt.xlabel("States")
plt.ylabel("Number of Women Powerlifters")
plt.title("Bar Chart For Top 21 to 30 States for Women")
plt.xticks(rotation=0)
plt.show()
